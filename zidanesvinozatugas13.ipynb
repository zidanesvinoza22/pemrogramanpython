# %% [markdown]
# <a href="https://colab.research.google.com/github/zidanesvinoza22/pemrogramanpython/blob/main/zidanesvinozatugas13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Grafik 1- frekuensi 1800 Mhz

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
f=1800 #MHz
zona='urban'
zona2='suburban'
zona3='open'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
print(d)
# Out:
# [626 375 293 618 222 397 662 604 299 608 462 440 364 459 423 302 610 222
#  404 397 333 371 529 249 253 363 330 233 686 606 560 527 386 587 238 502
#  511 401 201 615 478 599 379 219 591 238 313 641 405 501 645 218 530 294
#  656 408 331 389 253 285 242 370 223 578 307 670 302 454 423 427 326 454
#  629 237 534 461 399 237 521 571 290 347 508 680 503 609 646 311 257 412
#  464 386 699 697 322 388 575 633 541 317 572 639 694 240 523 470 442 347
#  354 405 382 505 506 215 612 677 208 595 243 687 540 311 309 672 539 502
#  304 440 281 650 326 291 576 468 338 479 387 208 566 356 268 490 374 663
#  208 224 450 459 272 645 268 652 517 341 249 644 361 278 642 381 218 528
#  562 331 615 380 595 262 407 572 653 216 389 384 488 425 611 242 554 256
#  490 695 616 416 338 462 467 227 559 583 643 324 296 391 647 364 231 221
#  317 682]

# %%
LpUrban=cos(f,zona,tower,user,d)
LpSuburban=cos(f,zona2,tower,user,d)
LpOpen=cos(f,zona3,tower,user,d)

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Suburban_sort=LpSuburban[np.argsort(d)]
Open_sort=LpOpen[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'r-', label='Urban')
plt.plot(d_sort,Suburban_sort,'k-', label='Suburban')
plt.plot(d_sort,Open_sort,'g-', label='Open')
plt.legend()
plt.title('Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %% [markdown]
# Grafik 2 - Model Urban

# %%
f=700 #MHz
f2=900 #MHz
f3=1800 #MHz
zona='urban'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
LpUrban=cos(f,zona,tower,user,d)
LpUrban2=cos(f2,zona,tower,user,d)
LpUrban3=cos(f3,zona,tower,user,d)

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Urban2_sort=LpUrban2[np.argsort(d)]
Urban3_sort=LpUrban3[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'r-', label='700 Mhz')
plt.plot(d_sort,Urban2_sort,'k-', label='900 Mhz')
plt.plot(d_sort,Urban3_sort,'g-', label='1800 Mhz')
plt.legend()
plt.title('Model Urban')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()
